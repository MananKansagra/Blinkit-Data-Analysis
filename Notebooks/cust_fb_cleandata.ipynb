# %%
import pandas as pd

# %%
df = pd.read_csv("data/blinkit_customer_feedback.csv")
df
# Out:
#       feedback_id    order_id  customer_id  rating  \
# 0         2234710  1961864118     30065862       4
# 1         5450964  1549769649      9573071       3
# 2          482108  9185164487     45477575       3
# 3         4823104  9644738826     88067569       4
# 4         3537464  5427684290     83298567       3
# ...           ...         ...          ...     ...
# 4995      9024060  1669690997     62600289       3
# 4996      4715968  8340761903     53640286       3
# 4997      9621021  5936301790     87059497       4
# 4998      1134095  5710579377     67310893       4
# 4999      6578433  2494813730     28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# ...

# %%
data = pd.DataFrame({'rating': [1, 2, 3, 4, 5]})
data['experience'] = data['rating'].map({1: 'very poor', 2: 'poor', 3: 'average', 4: 'good', 5: 'excellent'})
df
# Out:
#       feedback_id    order_id  customer_id  rating  \
# 0         2234710  1961864118     30065862       4
# 1         5450964  1549769649      9573071       3
# 2          482108  9185164487     45477575       3
# 3         4823104  9644738826     88067569       4
# 4         3537464  5427684290     83298567       3
# ...           ...         ...          ...     ...
# 4995      9024060  1669690997     62600289       3
# 4996      4715968  8340761903     53640286       3
# 4997      9621021  5936301790     87059497       4
# 4998      1134095  5710579377     67310893       4
# 4999      6578433  2494813730     28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
import pandas as pd

# 🔹 Step 1: Load your dataset from file path
# Replace 'your_file_path.csv' with your actual path (CSV or Excel)
df = pd.read_csv('data/blinkit_customer_feedback.csv')    # or pd.read_excel('your_file_path.xlsx')

# 🔹 Step 2: Define the mapping from rating to experience
rating_map = {
    1: "Very Poor",
    2: "Poor",
    3: "Average",
    4: "Good",
    5: "Excellent"
}

# 🔹 Step 3: Create the new column 'experience' based on 'rating'
df['experience'] = df['rating'].map(rating_map)
# Save the DataFrame to Excel file
df.to_csv("experience.csv", index=False)
df
# Out:
#       feedback_id    order_id  customer_id  rating  \
# 0         2234710  1961864118     30065862       4
# 1         5450964  1549769649      9573071       3
# 2          482108  9185164487     45477575       3
# 3         4823104  9644738826     88067569       4
# 4         3537464  5427684290     83298567       3
# ...           ...         ...          ...     ...
# 4995      9024060  1669690997     62600289       3
# 4996      4715968  8340761903     53640286       3
# 4997      9621021  5936301790     87059497       4
# 4998      1134095  5710579377     67310893       4
# 4999      6578433  2494813730     28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# ...
